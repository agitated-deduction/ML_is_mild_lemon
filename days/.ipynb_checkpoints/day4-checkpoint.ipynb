# %%
import pandas as pd
import numpy as np
seed = 2016
np.random.seed (seed)
y_0 = 1.0
alpha = -0.25
beta = 0.95
num = 10
y = pd.Series (y_0)
for i in range(num):
    y_t = alpha + (beta*y_0) + np.random.uniform(-1, 1)
    i += 1
    y.at[i]= y_t
    y_0 = y_t
    
print("Values of y are: \n",y)
# Out:
# Values of y are:
#  0     1.000000
# 1     1.493411
# 2     1.629219
# 3     1.864309
# 4     2.004397
# 5     1.578358
# 6     1.534571
# 7     0.657570
# 8     0.791785
# 9     0.996448
# 10    0.946840
# dtype: float64

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot(y)

# %%
seed = 2016
np.random.seed (seed)
y_0 = 1.0
alpha = -0.25
beta = 0.95
num = 1000
Y = pd.Series (y_0)
for i in range(num):
    y_t = alpha + (beta*y_0) + np.random.uniform(-1, 1)
    i += 1
    Y.at[i]= y_t
    y_0 = y_t

plt.plot(Y)

# %%
import numpy as np

# %%
np.random.seed (2016)
print("Seed = 2016", np.random.rand(3))
# Out:
# Seed = 2016 [0.89670536 0.73023921 0.78327576]

# %%
np.random.seed (1990)
print("Seed = 1990", np.random.rand(3))
# Out:
# Seed = 1990 [0.72197726 0.07755006 0.09762252]

# %%
np.random.seed (2016)
print("Seed = 2016", np.random.rand(3))
print("not reset = 2016", np.random.rand(3))
# Out:
# Seed = 2016 [0.89670536 0.73023921 0.78327576]
# not reset = 2016 [0.74165167 0.4620905  0.64256513]

# %%
ysort = y.sort_values()

print(ysort)#시리얼 데이터는 소팅을 절대 하면 안된다.
# Out:
# 7     0.657570
# 8     0.791785
# 10    0.946840
# 9     0.996448
# 0     1.000000
# 1     1.493411
# 6     1.534571
# 5     1.578358
# 2     1.629219
# 3     1.864309
# 4     2.004397
# dtype: float64

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot(ysort)

# %%
import numpy as np
import pandas as pd
import random
random.seed(2016)
sample_size = 100
sample = pd.Series(random.sample(range(-10000,10000), sample_size ))
x= sample/10000
y=x**2

# %%
print(x.head(10))
print(y.head(10))
# Out:
# 0    0.4703
# 1    0.8105
# 2   -0.1595
# 3   -0.7315
# 4   -0.0278
# 5   -0.5831
# 6   -0.7653
# 7    0.5950
# 8    0.5500
# 9   -0.6896
# dtype: float64
# 0    0.221182
# 1    0.656910
# 2    0.025440
# 3    0.535092
# 4    0.000773
# 5    0.340006
# 6    0.585684
# 7    0.354025
# 8    0.302500
# 9    0.475548
# dtype: float64

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.scatter(x,y)
#plt.plot(x,y)

# %%
print(x.describe())
# Out:
# count    100.000000
# mean      -0.011149
# std        0.589733
# min       -0.984100
# 25%       -0.522750
# 50%       -0.020600
# 75%        0.560025
# max        0.993400
# dtype: float64

# %%
# pandas 객체 --> numpy 객체

print(type(x))
x = np.array(x).reshape((len(x),))
print(type(x))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'numpy.ndarray'>

# %%
print(type(y))
y = np.array(y).reshape((len(y),))#string의 형태이기때문에 처리를 위해 reshape한다.
print(type(y))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'numpy.ndarray'>

# %%
# 1-dim --> 2-dim

print(x.shape)
# Out:
# (100,)

# %%
x = x.reshape(-1,1) #-1은 전부를 뜻함.
print(x.shape)
# Out:
# (100, 1)

# %%
from sklearn.neural_network import MLPRegressor

model = MLPRegressor(activation = 'tanh', hidden_layer_sizes=[10, 7, 4], max_iter = 100, 
                     learning_rate_init = 0.05)

model.fit(x,y)
# Out:
# MLPRegressor(activation='tanh', alpha=0.0001, batch_size='auto', beta_1=0.9,
#              beta_2=0.999, early_stopping=False, epsilon=1e-08,
#              hidden_layer_sizes=[10, 7, 4], learning_rate='constant',
#              learning_rate_init=0.05, max_fun=15000, max_iter=100, momentum=0.9,
#              n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#              random_state=None, shuffle=True, solver='adam', tol=0.0001,
#              validation_fraction=0.1, verbose=False, warm_start=False)

# %%
from sklearn.metrics import r2_score
print(r2_score(y, model.predict(x)))
# Out:
# 0.9950544282535112

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.scatter(x, y, marker = '^',  label = "y_true")
plt.scatter(x, model.predict(x), marker = 'o', label = "y_pred" )
plt.legend( )

# %%
td = (0.5, 0.2, 0.3,0.7,0.9)
td = np.array(td).reshape((len(td),))
td = td.reshape(-1,1)
model.predict(td)
# Out:
# array([0.25371604, 0.04795962, 0.09153938, 0.52002067, 0.80170205])

# %%
import numpy as np
import pandas as pd

#location = "C:\\TimeSeriesAnalysisWithDNN\\Data\\gas_con_2010_2019.xls"
location = "2010_2019.xls"

# %%
# pandas ExcelFile method 이용하여 excel 파일 불러옴

Excel_file = pd.ExcelFile(location)

# %%
# 스프레드시트 파일의 워크시트 이름 확인

print(Excel_file.sheet_names)
# Out:
# ['Gas Consumption Monthly', 'Sheet2', 'Sheet3']

# %%
# 워크시트의 데이터를 Dataframe 으로 저장하고 정보확인

spreadsheet = Excel_file.parse('Gas Consumption Monthly')
print(spreadsheet.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   DATE         110 non-null    datetime64[ns]
#  1   Consumption  110 non-null    int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 1.8 KB
# None

# %%
print(spreadsheet)
# Out:
#           DATE  Consumption
# 0   2010-01-01         5123
# 1   2010-02-01         5147
# 2   2010-03-01         5595
# 3   2010-04-01         5475
# 4   2010-05-01         5934
# ..         ...          ...
# 105 2018-10-01         5638
# 106 2018-11-01         6983
# 107 2018-12-01         6936
# 108 2019-01-01         7325
# 109 2019-02-01         6249
#
# [110 rows x 2 columns]

# %%
# Consumption: 월별 휘발유 소비량. 타겟 변수로 정함. data 객체에 저장

data = spreadsheet['Consumption']

print(data.head())
# Out:
# 0    5123
# 1    5147
# 2    5595
# 3    5475
# 4    5934
# Name: Consumption, dtype: int64

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
#판다스 데이터에 대해 그림을 그려주기 위해
from pandas.plotting import register_matplotlib_converters 
register_matplotlib_converters()
plt.plot(spreadsheet['DATE'], spreadsheet['Consumption'])

# %%
# 데이터 저장
#location = "C:\\TimeSeriesAnalysisWithDNN\\Data\\gas_con_2010_2019.csv"
location = "2010_2019.csv"
spreadsheet.to_csv(location)

# %%
# 정규화를 위해 sklearn 모듈의 MinMaxScaler 사용

from sklearn import preprocessing
scaler = preprocessing.MinMaxScaler(feature_range = (0,1))
print(scaler)

#> MinMaxScaler(copy = True, feature_range=(0, 1))
#> copy = True 가 기본 옵션.
#> 입력이 numpy array 인 경우 copy = False 로 두면 in-place row normalization 가능
#> 입력이 pandas Series 이므로 copy = True 로 둠
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
# pandas 객체에서 numpy 객체로 전환

x = data
print(type(x))
# Out:
# <class 'pandas.core.series.Series'>

# %%
x = np.array(x).reshape((len(x),))
print(type(x))
# Out:
# <class 'numpy.ndarray'>

# %%
x[0:6]
# Out:
# array([5123, 5147, 5595, 5475, 5934, 5484], dtype=int64)

# %%
# 1-dim --> 2-dim

x = x.reshape(-1,1)

# %%
x[0:6]
# Out:
# array([[5123],
#        [5147],
#        [5595],
#        [5475],
#        [5934],
#        [5484]], dtype=int64)

# %%
# scale x

x = scaler.fit_transform(x)

# %%
# 2-dim --> 1-dim

x = x.reshape(-1)
print(x.shape)
# Out:
# (110,)

# %%
print(round(x.min(),2))
print(round(x.max(),2))
# Out:
# 0.0
# 1.0

# %%
from statsmodels.tsa.stattools import pacf
x_pacf = pacf(x, nlags = 40, method = 'ols')
print(x_pacf)
# Out:
# [ 1.00000000e+00  5.52417161e-01  2.16410392e-01  1.31076156e-01
#   1.62099197e-01  3.25874388e-02 -3.20683723e-01  4.32480244e-01
#   2.50371353e-01  1.91479355e-01  3.06928461e-01  2.54655996e-01
#   6.03343499e-01  1.17097991e-01  3.14531637e-02  1.05177659e-01
#   1.90033961e-01  8.83438916e-04 -4.70165683e-02 -8.63496148e-02
#   2.90618500e-01 -4.51807690e-02 -5.57034556e-02 -6.17094771e-02
#   2.40265914e-01  3.11518119e-02 -1.77290557e-01  2.26414295e-01
#   3.53080686e-02  1.73392005e-01 -4.09375916e-01 -8.82429489e-02
#  -1.31142602e-01  1.89275286e-01  1.23553603e-02  1.31651669e-01
#   4.64286603e-01  1.80034179e-01 -1.10826870e-01  2.45217511e-01
#   3.08485094e-01]

# %%
from statsmodels.graphics.tsaplots import plot_pacf
plot_pacf(x, lags=40, method='ols', title='Partial Autocorrelation')

# %%
from nnet_ts import *
count = 0
ahead = 12
pred = []
while(count < ahead):
    end = len(x) - ahead + count
    np.random.seed(2016)
    fit1 = TimeSeriesNnet(hidden_layers = [40, 20, 10, 5], activation_functions = ['tanh', 'tanh', 'tanh', 'tanh'])
    fit1.fit(x[0:end], lag = 12, epochs = 50)
    out = fit1.predict_ahead(n_ahead = 1)
    print("Obs: ", count + 1, " x= ", round(x[end], 4), 
         "prediction = ", round(pd.Series(out), 4))
    pred.append(out)
    count += 1
# Out:
# Using TensorFlow backend.
# INFO:Building regressor matrix
# INFO:Scaling data
# INFO:Checking network consistency
# INFO:Training neural net
# D:\ana\lib\site-packages\nnet_ts\TimeSeriesNnet.py:60: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   self.nn.fit(self.X, self.y, nb_epoch = self.epochs, verbose = self.verbose)
# INFO:Building regressor matrix
# INFO:Scaling data
# INFO:Checking network consistency
# INFO:Training neural net
# Obs:  1  x=  0.549 prediction =  0    0.5842
# dtype: float64
# D:\ana\lib\site-packages\nnet_ts\TimeSeriesNnet.py:60: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   self.nn.fit(self.X, self.y, nb_epoch = self.epochs, verbose = self.verbose)
# INFO:Building regressor matrix
# INFO:Scaling data
# INFO:Checking network consistency
# INFO:Training neural net
# Obs:  2  x=  0.4963 prediction =  0    0.6136
# dtype: float64
# D:\ana\lib\site-packages\nnet_ts\TimeSeriesNnet.py:60: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   self.nn.fit(self.X, self.y, nb_epoch = self.epochs, verbose = self.verbose)
# INFO:Building regressor matrix
# INFO:Scaling data
# INFO:Checking network consistency
# INFO:Training neural net
# Obs:  3  x=  0.5543 prediction =  0    0.7277
# dtype: float64
# D:\ana\lib\site-packages\nnet_ts\TimeSeriesNnet.py:60: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   self.nn.fit(self.X, self.y, nb_epoch = self.epochs, verbose = self.verbose)
# INFO:Building regressor matrix
# INFO:Scaling data
# INFO:Checking network consistency
# INFO:Training neural net
# Obs:  4  x=  0.6422 prediction =  0    0.5426
# dtype: float64
# D:\ana\lib\site-packages\nnet_ts\TimeSeriesNnet.py:60: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   self.nn.fit(self.X, self.y, nb_epoch = self.epochs, verbose = self.verbose)
# INFO:Building regressor matrix
# INFO:Scaling data
# INFO:Checking network consistency
# INFO:Training neural net
# Obs:  5  x=  0.7212 prediction =  0    0.9143
# dtype: float64
# D:\ana\lib\site-packages\nnet_ts\TimeSeriesNnet.py:60: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   self.nn.fit(self.X, self.y, nb_epoch = self.epochs, verbose = self.verbose)
# INFO:Building regressor matrix
# INFO:Scaling data
# INFO:Checking network consistency
# INFO:Training neural net
# Obs:  6  x=  0.8076 prediction =  0    0.8347
# dtype: float64
# D:\ana\lib\site-packages\nnet_ts\TimeSeriesNnet.py:60: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   self.nn.fit(self.X, self.y, nb_epoch = self.epochs, verbose = self.verbose)
# INFO:Building regressor matrix
# INFO:Scaling data
# INFO:Checking network consistency
# INFO:Training neural net
# Obs:  7  x=  0.6433 prediction =  0    0.6381
# dtype: float64
# D:\ana\lib\site-packages\nnet_ts\TimeSeriesNnet.py:60: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   self.nn.fit(self.X, self.y, nb_epoch = self.epochs, verbose = self.verbose)
# INFO:Building regressor matrix
# INFO:Scaling data
# INFO:Checking network consistency
# INFO:Training neural net
# Obs:  8  x=  0.1927 prediction =  0    0.6664
# dtype: float64
# D:\ana\lib\site-packages\nnet_ts\TimeSeriesNnet.py:60: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   self.nn.fit(self.X, self.y, nb_epoch = self.epochs, verbose = self.verbose)
# INFO:Building regressor matrix
# INFO:Scaling data
# INFO:Checking network consistency
# INFO:Training neural net
# Obs:  9  x=  0.6961 prediction =  0    0.496
# dtype: float64
# D:\ana\lib\site-packages\nnet_ts\TimeSeriesNnet.py:60: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   self.nn.fit(self.X, self.y, nb_epoch = self.epochs, verbose = self.verbose)
# INFO:Building regressor matrix
# INFO:Scaling data
# INFO:Checking network consistency
# INFO:Training neural net
# Obs:  10  x=  0.6785 prediction =  0    0.7026
# dtype: float64
# D:\ana\lib\site-packages\nnet_ts\TimeSeriesNnet.py:60: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   self.nn.fit(self.X, self.y, nb_epoch = self.epochs, verbose = self.verbose)
# INFO:Building regressor matrix
# INFO:Scaling data
# INFO:Checking network consistency
# INFO:Training neural net
# Obs:  11  x=  0.8241 prediction =  0    0.5845
# dtype: float64
# D:\ana\lib\site-packages\nnet_ts\TimeSeriesNnet.py:60: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   self.nn.fit(self.X, self.y, nb_epoch = self.epochs, verbose = self.verbose)
# Obs:  12  x=  0.4214 prediction =  0    0.4264
# dtype: float64

# %%
pred1 = scaler.inverse_transform(pred)
pred1 = np.exp(pred1)
print(np.round(pred1, 1))
# Out:
# [[inf]
#  [inf]
#  [inf]
#  [inf]
#  [inf]
#  [inf]
#  [inf]
#  [inf]
#  [inf]
#  [inf]
#  [inf]
#  [inf]]
# D:\ana\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in exp

# %%
plt.plot(x[len(x) - ahead:len(x)], marker = '^', label = "Original series")
plt.plot(pred, marker = 'o', label = "Prediction")
plt.legend()
